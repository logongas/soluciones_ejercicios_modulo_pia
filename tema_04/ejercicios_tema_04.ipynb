# %%
#Ejercicio 1
import matplotlib.pyplot as plt
 
figure=plt.figure(figsize=(6, 6))
axes = figure.add_subplot(2,2,1)
axes = figure.add_subplot(2,2,2)
axes = figure.add_subplot(2,2,3)
axes = figure.add_subplot(2,2,4)

figure.suptitle("Ejercicio 1", fontsize=24)
figure.savefig("figura_ejercicio_1.png",facecolor="#FFFFFF",bbox_inches='tight')

# %%
#Ejercicio 2

filas=3
columnas=3

import matplotlib.pyplot as plt
 
figure=plt.figure(figsize=(9, 9))

for index in range(filas*columnas):
    axes = figure.add_subplot(filas,columnas,index+1)


figure.suptitle("Ejercicio 2", fontsize=24)
figure.savefig("figura_ejercicio_2.png",facecolor="#FFFFFF",bbox_inches='tight')

# %%
#Ejercicio 3

filas=3
columnas=2

import matplotlib.pyplot as plt
 
figure=plt.figure(figsize=(8, 9))

for index in range(filas*columnas):
    axes = figure.add_subplot(filas,columnas,index+1)


figure.suptitle("Ejercicio 3", fontsize=24)
figure.savefig("figura_ejercicio_3.png",facecolor="#FFFFFF",bbox_inches='tight')

# %%
#Ejercicio 4
import matplotlib.pyplot as plt
 
figure=plt.figure(figsize=(9, 6))
axes = figure.add_subplot(2,1,1)
axes = figure.add_subplot(2,3,4)
axes = figure.add_subplot(2,3,5)
axes = figure.add_subplot(2,3,6)

figure.suptitle("Ejercicio 4", fontsize=24)
figure.savefig("figura_ejercicio_4.png",facecolor="#FFFFFF",bbox_inches='tight')

# %%
#Ejercicio 5
import matplotlib.pyplot as plt
 
figure=plt.figure(figsize=(7, 9))



axes = figure.add_subplot(3,2,1)
axes = figure.add_subplot(3,2,2)
axes = figure.add_subplot(3,2,3)
axes = figure.add_subplot(3,2,4)
axes = figure.add_subplot(3,1,3)


figure.suptitle("Ejercicio 5", fontsize=24)
figure.savefig("figura_ejercicio_5.png",facecolor="#FFFFFF",bbox_inches='tight')

# %%
#Ejercicio 6
import matplotlib.pyplot as plt
 
figure=plt.figure(figsize=(7, 9))

axes = figure.add_subplot(3,1,1)

axes = figure.add_subplot(3,2,3)
axes = figure.add_subplot(3,2,4)
axes = figure.add_subplot(3,2,5)
axes = figure.add_subplot(3,2,6)



figure.suptitle("Ejercicio 6", fontsize=24)
figure.savefig("figura_ejercicio_6.png",facecolor="#FFFFFF",bbox_inches='tight')

# %%
#Ejercicio 7
import matplotlib.pyplot as plt
 
figure=plt.figure(figsize=(9, 7))
axes = figure.add_subplot(3,3,(1,5))
axes = figure.add_subplot(3,3,3)
axes = figure.add_subplot(3,3,6)
axes = figure.add_subplot(3,3,7)
axes = figure.add_subplot(3,3,8)
axes = figure.add_subplot(3,3,9)


figure.suptitle("Ejercicio 7", fontsize=24)
figure.savefig("figura_ejercicio_7.png",facecolor="#FFFFFF",bbox_inches='tight')

# %%
#Ejercicio 8
import matplotlib.pyplot as plt
 
figure=plt.figure(figsize=(9, 7))
axes = figure.add_subplot(2,2,1,projection='3d')
axes = figure.add_subplot(2,2,2,projection='3d')
axes = figure.add_subplot(2,2,3)
axes = figure.add_subplot(2,2,4)


figure.suptitle("Ejercicio 8", fontsize=24)
figure.savefig("figura_ejercicio_8.png",facecolor="#FFFFFF",bbox_inches='tight')

# %%
#Ejercicio 9
import matplotlib.pyplot as plt
 
figure=plt.figure(figsize=(9, 9))
axes = figure.add_subplot(3,2,(1,2))
axes = figure.add_subplot(3,2,3,projection='3d')
axes = figure.add_subplot(3,2,4,projection='3d')
axes = figure.add_subplot(3,2,5,projection='3d')
axes = figure.add_subplot(3,2,6,projection='3d')


figure.suptitle("Ejercicio 9", fontsize=24)
figure.savefig("figura_ejercicio_9.png",facecolor="#FFFFFF",bbox_inches='tight')

# %%
#Ejercicio 10

x=[-3.       , -2.57142857, -2.14285714, -1.71428571, -1.28571429, -0.85714286, -0.42857143,  0.        ,  0.42857143,  0.85714286, 1.28571429,  1.71428571,  2.14285714,  2.57142857,  3.       ]
y=[0.00443185, 0.01462444 , 0.04016108 , 0.09178317 , 0.17456307 , 0.27629519 , 0.36393672 , 0.39894228 , 0.36393672 , 0.27629519 , 0.17456307, 0.09178317 , 0.04016108 , 0.01462444 , 0.00443185]

figure=plt.figure(figsize=(3, 3))
axes = figure.add_subplot()
axes.scatter(x,y)

figure=plt.figure(figsize=(3, 3))
axes = figure.add_subplot()
axes.plot(x,y)

figure=plt.figure(figsize=(3, 3))
axes = figure.add_subplot()
axes.bar(x,y)

figure=plt.figure(figsize=(3, 3))
axes = figure.add_subplot()
axes.plot(x,y)
axes.scatter(x,y)

# %%
#Ejercicio 11

x=[-3.       , -2.57142857, -2.14285714, -1.71428571, -1.28571429, -0.85714286, -0.42857143,  0.        ,  0.42857143,  0.85714286, 1.28571429,  1.71428571,  2.14285714,  2.57142857,  3.       ]
y=[0.00443185, 0.01462444 , 0.04016108 , 0.09178317 , 0.17456307 , 0.27629519 , 0.36393672 , 0.39894228 , 0.36393672 , 0.27629519 , 0.17456307, 0.09178317 , 0.04016108 , 0.01462444 , 0.00443185]

figure=plt.figure(figsize=(8, 8))
axes = figure.add_subplot(2,2,1)
axes.set_title("Puntos", fontsize=20)
axes.scatter(x,y)
axes = figure.add_subplot(2,2,2)
axes.set_title("Lineas", fontsize=20)
axes.plot(x,y)
axes = figure.add_subplot(2,2,3)
axes.set_title("Barras", fontsize=20)
axes.bar(x,y)
axes = figure.add_subplot(2,2,4)
axes.set_title("Puntos y Lineas", fontsize=20)
axes.plot(x,y)
axes.scatter(x,y)

figure.suptitle("Ejercicio 11", fontsize=24)
figure.savefig("figura_ejercicio_11.png",facecolor="#FFFFFF",bbox_inches='tight')

# %%
#Ejercicio 12
import numpy as np

x=np.linspace(-2,2,300)
y=x**2

figure=plt.figure(figsize=(5, 5))
axes = figure.add_subplot(1,1,1)
axes.plot(x,y)
axes.set_xlabel('x', fontsize=15,labelpad=20,color="#003B80")  
axes.set_ylabel('x²', fontsize=15,labelpad=20,color="#003B80")


figure.suptitle("Ejercicio 12", fontsize=24)
figure.savefig("figura_ejercicio_12.png",facecolor="#FFFFFF",bbox_inches='tight')

# %%
#Ejercicio 13
import numpy as np

x=np.linspace(-2,2,300)
y=np.abs(x)

figure=plt.figure(figsize=(5, 5))
axes = figure.add_subplot(1,1,1)
axes.plot(x,y)
axes.set_xlabel('x', fontsize=15,labelpad=20,color="#003B80")  
axes.set_ylabel('|x|', fontsize=15,labelpad=20,color="#003B80")


figure.suptitle("Ejercicio 13", fontsize=24)
figure.savefig("figura_ejercicio_13.png",facecolor="#FFFFFF",bbox_inches='tight')

# %%
#Ejercicio 14
import numpy as np

x=np.linspace(-2,2,300)
y1=x**2
y2=np.abs(x)

figure=plt.figure(figsize=(7, 6))
axes = figure.add_subplot(1,1,1)
axes.plot(x,y1,color="#00FF00",label="x²")
axes.plot(x,y2,color="#FF0000",label="|x|")
axes.set_xlabel('x', fontsize=15,labelpad=20,color="#003B80")  
axes.legend(fontsize=15,facecolor='#CDCDCD',labelcolor="#000000")


figure.suptitle("Ejercicio 14", fontsize=24)
figure.savefig("figura_ejercicio_14.png",facecolor="#FFFFFF",bbox_inches='tight')

# %%
#Ejercicio 15.A
def get_data():
    size=150
    num_tipos=10
    pendiente_base=-8
    np.random.seed(6)
 
    x=np.array([])
    y=np.array([])    
    z=np.array([])
    x_ini=0
    y_ini=50
    z_ini=0
    x_ancho=8
    y_ancho=60
    x_inc=2
    y_inc=y_ancho-3
    z_int=10
 
    for i in range(0,num_tipos):
        pendiente=np.random.uniform(pendiente_base-0.4,pendiente_base+0.4,1)[0]
        x_tipo=np.random.uniform(x_ini,x_ini+x_ancho,size)
        y_tipo=np.random.uniform(y_ini,y_ini+y_ancho,size)+pendiente*x_tipo
        z_tipo=np.full(size, z_ini)
 
        x=np.concatenate((x,x_tipo))
        y=np.concatenate((y,y_tipo))
        z=np.concatenate((z,z_tipo))
 
        x_ini=x_ini+x_inc
        y_ini=y_ini+y_inc
        z_ini=z_ini+z_int
 
    return x,y,z


x,y,z=get_data()

figure=plt.figure(figsize=(10, 8))
axes = figure.add_subplot(1,1,1)
axes.scatter(x,y,c="#82C4F3") 
axes.set_xlabel('Vacuna inyectada (ml)', fontsize=15,labelpad=20,color="#003B80")  
axes.set_ylabel('Nº Pacientes enfermados cada 100.000 habitantes', fontsize=15,labelpad=20,color="#003B80")
figure.suptitle("Ejercicio 15.A", fontsize=24)
# Out:
# Text(0.5, 0.98, 'Ejercicio 15.A')

# %%
#Ejercicio 15.B
from sklearn.linear_model import LinearRegression

def get_data():
    size=150
    num_tipos=10
    pendiente_base=-8
    np.random.seed(6)
 
    x=np.array([])
    y=np.array([])    
    z=np.array([])
    x_ini=0
    y_ini=50
    z_ini=0
    x_ancho=8
    y_ancho=60
    x_inc=2
    y_inc=y_ancho-3
    z_int=10
 
    for i in range(0,num_tipos):
        pendiente=np.random.uniform(pendiente_base-0.4,pendiente_base+0.4,1)[0]
        x_tipo=np.random.uniform(x_ini,x_ini+x_ancho,size)
        y_tipo=np.random.uniform(y_ini,y_ini+y_ancho,size)+pendiente*x_tipo
        z_tipo=np.full(size, z_ini)
 
        x=np.concatenate((x,x_tipo))
        y=np.concatenate((y,y_tipo))
        z=np.concatenate((z,z_tipo))
 
        x_ini=x_ini+x_inc
        y_ini=y_ini+y_inc
        z_ini=z_ini+z_int
 
    return x,y,z


x,y,z=get_data()

figure=plt.figure(figsize=(10, 8))
axes = figure.add_subplot(1,1,1)
axes.scatter(x,y,c="#82C4F3") 
axes.set_xlabel('Vacuna inyectada (ml)', fontsize=15,labelpad=20,color="#003B80")  
axes.set_ylabel('Nº Pacientes enfermados cada 100.000 habitantes', fontsize=15,labelpad=20,color="#003B80")
figure.suptitle("Ejercicio 15.B", fontsize=24)


def get_recta_regresion(x,y):
    model = LinearRegression()
    model.fit(x.reshape(-1, 1), y.reshape(-1, 1))
    x_init=x.min()
    y_init=model.predict([[x_init]])[0,0]
    x_fin=x.max()
    y_fin=model.predict([[x_fin]])[0,0]

    return [x_init,x_fin],[y_init,y_fin]

x_recta_regresion,y_recta_regresion=get_recta_regresion(x,y)

axes.plot(x_recta_regresion,y_recta_regresion,c="#000000")


#La relación es que cuanta más vacuna inyectada más probabilidad hay que enfermar de COVID

# %%
#Ejercicio 15.C
def get_data():
    size=150
    num_tipos=10
    pendiente_base=-8
    np.random.seed(6)
 
    x=np.array([])
    y=np.array([])    
    z=np.array([])
    x_ini=0
    y_ini=50
    z_ini=0
    x_ancho=8
    y_ancho=60
    x_inc=2
    y_inc=y_ancho-3
    z_int=10
 
    for i in range(0,num_tipos):
        pendiente=np.random.uniform(pendiente_base-0.4,pendiente_base+0.4,1)[0]
        x_tipo=np.random.uniform(x_ini,x_ini+x_ancho,size)
        y_tipo=np.random.uniform(y_ini,y_ini+y_ancho,size)+pendiente*x_tipo
        z_tipo=np.full(size, z_ini)
 
        x=np.concatenate((x,x_tipo))
        y=np.concatenate((y,y_tipo))
        z=np.concatenate((z,z_tipo))
 
        x_ini=x_ini+x_inc
        y_ini=y_ini+y_inc
        z_ini=z_ini+z_int
 
    return x,y,z


x,y,z=get_data()

figure=plt.figure(figsize=(10, 8))
axes = figure.add_subplot(1,1,1)
scatter=axes.scatter(x,y,c=z) 
axes.set_xlabel('Vacuna inyectada (ml)', fontsize=15,labelpad=20,color="#003B80")  
axes.set_ylabel('Nº Pacientes enfermados cada 100.000 habitantes', fontsize=15,labelpad=20,color="#003B80")
figure.suptitle("Ejercicio 15.C", fontsize=24)
labels_tipos=["Edad [0,10[","Edad [10,20[","Edad [20,30[","Edad [30,40[","Edad [40,50[","Edad [50,60[","Edad [60,70[","Edad [70,80[","Edad [80,90[","Edad [90,100["]
axes.legend(handles=scatter.legend_elements()[0],labels=labels_tipos)

# %%
#Ejercicio 15.D
def get_data():
    size=150
    num_tipos=10
    pendiente_base=-8
    np.random.seed(6)
 
    x=np.array([])
    y=np.array([])    
    z=np.array([])
    x_ini=0
    y_ini=50
    z_ini=0
    x_ancho=8
    y_ancho=60
    x_inc=2
    y_inc=y_ancho-3
    z_int=10
 
    for i in range(0,num_tipos):
        pendiente=np.random.uniform(pendiente_base-0.4,pendiente_base+0.4,1)[0]
        x_tipo=np.random.uniform(x_ini,x_ini+x_ancho,size)
        y_tipo=np.random.uniform(y_ini,y_ini+y_ancho,size)+pendiente*x_tipo
        z_tipo=np.full(size, z_ini)
 
        x=np.concatenate((x,x_tipo))
        y=np.concatenate((y,y_tipo))
        z=np.concatenate((z,z_tipo))
 
        x_ini=x_ini+x_inc
        y_ini=y_ini+y_inc
        z_ini=z_ini+z_int
 
    return x,y,z


x,y,z=get_data()

figure=plt.figure(figsize=(10, 8))
axes = figure.add_subplot(1,1,1)
scatter=axes.scatter(x,y,c=z) 
axes.set_xlabel('Vacuna inyectada (ml)', fontsize=15,labelpad=20,color="#003B80")  
axes.set_ylabel('Nº Pacientes enfermados cada 100.000 habitantes', fontsize=15,labelpad=20,color="#003B80")
figure.suptitle("Ejercicio 15.D", fontsize=24)
labels_tipos=["Edad [0,10[","Edad [10,20[","Edad [20,30[","Edad [30,40[","Edad [40,50[","Edad [50,60[","Edad [60,70[","Edad [70,80[","Edad [80,90[","Edad [90,100["]
axes.legend(handles=scatter.legend_elements()[0],labels=labels_tipos)


def get_recta_regresion(x,y):
    model = LinearRegression()
    model.fit(x.reshape(-1, 1), y.reshape(-1, 1))
    x_init=x.min()
    y_init=model.predict([[x_init]])[0,0]
    x_fin=x.max()
    y_fin=model.predict([[x_fin]])[0,0]

    return [x_init,x_fin],[y_init,y_fin]

for index,edad in enumerate(np.unique(z)):
    x_edad=x[z==edad]
    y_edad=y[z==edad]

    x_recta_regresion,y_recta_regresion=get_recta_regresion(x_edad,y_edad)
    axes.plot(x_recta_regresion,y_recta_regresion,c="#000000")


#La relación ahora es que a mayor edad hace falta más dosis de vacuna 
#pero que cuanta mayor dosis se le aplica a cada rango de edad , menor probabilidad hay de enfermar

# %%
#Ejercicio 15.E

#Que cuantos más policias negros hay , mayor el el número de delitos.


#Que cuanto mayor es el PIB hay mas policias negros en ese estado.
#pero que cuantos más policias negros hay en un estado, menos delitos hay.

# %%
#Ejercicio 16
from matplotlib.colors import LightSource

x=np.linspace(-15,15,100)
y=np.linspace(-15,15,100)
x,y=np.meshgrid(x,y)
z=np.sin(np.sqrt(x**2+y**2+4))/np.sqrt(x**2+y**2+4)


light_source = LightSource()
facecolors = light_source.shade(z,plt.cm.cool, blend_mode='soft')

figure=plt.figure(figsize=(10, 8))
axes = figure.add_subplot(1,1,1,projection='3d')
axes.plot_surface(x,y,z,facecolors=facecolors)
axes.set_xlabel('X', fontsize=15,color="#003B80")  
axes.set_ylabel('Y', fontsize=15,color="#003B80")
axes.set_zlabel('Z', fontsize=15,color="#003B80")
figure.colorbar(plt.cm.ScalarMappable(cmap=plt.cm.cool),ax=axes, shrink = 0.5)
figure.tight_layout()

# %%
#Ejercicio 17

x=np.linspace(-15,15,100)
y=np.linspace(-15,15,100)
x,y=np.meshgrid(x,y)
z=np.sin(np.sqrt(x**2+y**2+4))/np.sqrt(x**2+y**2+4)


figure=plt.figure(figsize=(10, 8))
axes = figure.add_subplot(1,1,1)
axes.contourf(x,y,z,cmap='cool')
axes.set_xlabel('X', fontsize=15,color="#003B80")  
axes.set_ylabel('Y', fontsize=15,color="#003B80")
figure.colorbar(plt.cm.ScalarMappable(cmap=plt.cm.cool),ax=axes, shrink = 0.5)
figure.tight_layout()

# %%
#Ejercicio 18
import seaborn as sns
 
altura_hombres=[182.74607218, 169.32946152, 169.83096949, 166.56218827,
       178.19244578, 159.19076782, 183.46887059, 168.43275859,
       174.91423458, 171.50377775, 181.77264762, 160.63915574,
       171.06549678, 170.69567387, 179.80261665, 166.4006524 ,
       171.96543075, 167.73284949, 173.25328248, 176.49689128,
       166.39628494, 179.86834226, 178.40954432, 176.01496603,
       178.4051357 , 168.89763284, 172.26265865, 167.38538339,
       171.39267152, 176.1821328 , 168.85003549, 170.61947884,
       168.8769638 , 167.92876615, 168.97252321, 172.92401241,
       166.29613791, 174.40649419, 182.95881306, 177.45226496,
       171.84898669, 167.67422622, 168.51705024, 183.15472761,
       173.30484653, 169.17802612, 174.14549291, 185.60153082,
       173.72095371, 176.70321866, 174.80102192, 170.88650092,
       166.14489081, 170.90394367, 171.7466346 , 176.51973915,
       178.03390048, 178.58661249, 174.71352395, 178.31084699,
       168.47361235, 180.51720893, 176.07757892, 171.21144299,
       175.93110888, 172.54656972, 179.78977632, 182.1189009 ,
       186.11345244, 164.62102199, 164.33531717, 169.97320482,
       173.96022242, 178.25701353, 174.89380968, 160.86679271,
       171.16277592, 177.96784786, 174.38056841, 177.57206708,
       171.66603114, 171.79545159, 174.11936835, 175.46030988,
       174.18979832, 173.71405187, 168.97602628, 175.26538272,
       173.73092763, 179.77690345, 180.19350728, 174.1109385 ,
       170.7482903 , 169.16761756, 175.54096612, 173.46404041,
       170.93687795, 173.26158114, 169.27999494, 177.1881922 ]
altura_mujeres=[159.31722861, 169.34704623, 164.42094985, 165.56147114,
       155.43052893, 163.0162946 , 166.44333871, 156.27779639,
       160.40268896, 162.19568728, 153.76129608, 163.89095635,
       167.07696389, 156.84290436, 164.10327587, 154.12629953,
       161.76782694, 152.30536587, 168.72850625, 164.45340323,
       161.85229826, 157.34903028, 169.64253558, 173.8026105 ,
       150.85210881, 169.41698418, 171.76590452, 164.02807018,
       154.80439181, 167.18007191, 160.91447819, 158.37647623,
       154.61965119, 165.30322498, 166.7568412 , 158.25881562,
       165.12345802, 155.13395166, 166.81116619, 162.27940379,
       160.88058137, 161.38952476, 167.21331694, 166.50246984,
       165.17679195, 162.82620726, 162.46692677, 165.71028157,
       163.39496736, 166.09530844, 160.13929936, 147.39097342,
       168.23294761, 175.12187788, 164.64818666, 161.3990686 ,
       161.18133154, 161.28567487, 162.10445645, 155.26788763,
       158.89743325, 156.01783903, 163.49279497, 160.22015309,
       164.97126794, 160.95178104, 167.91801113, 163.28120341,
       175.14419837, 150.62183446, 158.11849987, 167.40892135,
       177.16995424, 160.50819133, 162.26201396, 160.64211454,
       169.98874268, 160.27615282, 166.08041904, 160.08119041,
       154.36464747, 163.88128632, 165.01910888, 169.7593553 ,
       161.33731784, 158.29582762, 165.37656658, 163.44442255,
       163.68399046, 161.56132378, 168.96203142, 164.2169563 ,
       173.42795225, 168.66634019, 165.95429878, 152.23536996,
       165.61391568, 164.52169322, 166.86571004, 168.26665257]



figure=plt.figure(figsize = (6, 6))
axes = figure.add_subplot()
sns.kdeplot(x=altura_hombres,fill=True,ax=axes)
sns.kdeplot(x=altura_mujeres,fill=True,ax=axes)
axes.set_xlabel('Edad', fontsize=15,color="#003B80")  
axes.set_ylabel('Densidad', fontsize=15,color="#003B80")
axes.legend(labels=['Hombres', 'Mujeres'])

# %%
#Ejercicio 19
import seaborn as sns
 
altura_hombres=[182.74607218, 169.32946152, 169.83096949, 166.56218827,
       178.19244578, 159.19076782, 183.46887059, 168.43275859,
       174.91423458, 171.50377775, 181.77264762, 160.63915574,
       171.06549678, 170.69567387, 179.80261665, 166.4006524 ,
       171.96543075, 167.73284949, 173.25328248, 176.49689128,
       166.39628494, 179.86834226, 178.40954432, 176.01496603,
       178.4051357 , 168.89763284, 172.26265865, 167.38538339,
       171.39267152, 176.1821328 , 168.85003549, 170.61947884,
       168.8769638 , 167.92876615, 168.97252321, 172.92401241,
       166.29613791, 174.40649419, 182.95881306, 177.45226496,
       171.84898669, 167.67422622, 168.51705024, 183.15472761,
       173.30484653, 169.17802612, 174.14549291, 185.60153082,
       173.72095371, 176.70321866, 174.80102192, 170.88650092,
       166.14489081, 170.90394367, 171.7466346 , 176.51973915,
       178.03390048, 178.58661249, 174.71352395, 178.31084699,
       168.47361235, 180.51720893, 176.07757892, 171.21144299,
       175.93110888, 172.54656972, 179.78977632, 182.1189009 ,
       186.11345244, 164.62102199, 164.33531717, 169.97320482,
       173.96022242, 178.25701353, 174.89380968, 160.86679271,
       171.16277592, 177.96784786, 174.38056841, 177.57206708,
       171.66603114, 171.79545159, 174.11936835, 175.46030988,
       174.18979832, 173.71405187, 168.97602628, 175.26538272,
       173.73092763, 179.77690345, 180.19350728, 174.1109385 ,
       170.7482903 , 169.16761756, 175.54096612, 173.46404041,
       170.93687795, 173.26158114, 169.27999494, 177.1881922 ]
altura_mujeres=[159.31722861, 169.34704623, 164.42094985, 165.56147114,
       155.43052893, 163.0162946 , 166.44333871, 156.27779639,
       160.40268896, 162.19568728, 153.76129608, 163.89095635,
       167.07696389, 156.84290436, 164.10327587, 154.12629953,
       161.76782694, 152.30536587, 168.72850625, 164.45340323,
       161.85229826, 157.34903028, 169.64253558, 173.8026105 ,
       150.85210881, 169.41698418, 171.76590452, 164.02807018,
       154.80439181, 167.18007191, 160.91447819, 158.37647623,
       154.61965119, 165.30322498, 166.7568412 , 158.25881562,
       165.12345802, 155.13395166, 166.81116619, 162.27940379,
       160.88058137, 161.38952476, 167.21331694, 166.50246984,
       165.17679195, 162.82620726, 162.46692677, 165.71028157,
       163.39496736, 166.09530844, 160.13929936, 147.39097342,
       168.23294761, 175.12187788, 164.64818666, 161.3990686 ,
       161.18133154, 161.28567487, 162.10445645, 155.26788763,
       158.89743325, 156.01783903, 163.49279497, 160.22015309,
       164.97126794, 160.95178104, 167.91801113, 163.28120341,
       175.14419837, 150.62183446, 158.11849987, 167.40892135,
       177.16995424, 160.50819133, 162.26201396, 160.64211454,
       169.98874268, 160.27615282, 166.08041904, 160.08119041,
       154.36464747, 163.88128632, 165.01910888, 169.7593553 ,
       161.33731784, 158.29582762, 165.37656658, 163.44442255,
       163.68399046, 161.56132378, 168.96203142, 164.2169563 ,
       173.42795225, 168.66634019, 165.95429878, 152.23536996,
       165.61391568, 164.52169322, 166.86571004, 168.26665257]



figure=plt.figure(figsize = (6, 6))
axes = figure.add_subplot()
sns.histplot(x=altura_hombres,fill=True,ax=axes,color="#1DA0E2")
sns.histplot(x=altura_mujeres,fill=True,ax=axes,color="#57982F")
axes.set_xlabel('Edad', fontsize=15,color="#003B80")  
axes.set_ylabel('Densidad', fontsize=15,color="#003B80")
axes.legend(labels=['Hombres', 'Mujeres'])

# %%
#Ejercicio 20

import pandas as pd
df = pd.read_csv("fifa.csv")

figure=plt.figure(figsize=(10, 6))
axes = figure.add_subplot()

sns.scatterplot(x ='work_rate',
                    y = df['wage_eur'],
                    hue = "league_rank",
                    data = df,
                     palette = ["green", "red", "coral", "blue"],
                     legend="full",
                     alpha = 0.4,
                     ax=axes
                    )
 
max_wage_eur = df.groupby("work_rate")["wage_eur"].max()
#Making a line plot of max wages
sns.lineplot(data = max_wage_eur,
            ax = axes,
            color="grey")
axes.tick_params(axis= "x", rotation=90)
axes.set_xlabel("Work Rate")
axes.set_ylabel("Wage EUR")
figure.suptitle("Relationship between work rate and wage by league rank", fontsize = 18)
# Out:
# Text(0.5, 0.98, 'Relationship between work rate and wage by league rank')

# %%
#Ejercicio 21

from matplotlib.ticker import NullLocator
datos=np.genfromtxt("mario.csv",delimiter=",").astype(np.uint8)

datos=datos.reshape(41,31,3)

figure=plt.figure()
axes = figure.add_subplot()
axes.imshow(datos)

axes.spines['right'].set_visible(False)
axes.spines['top'].set_visible(False)
axes.spines['left'].set_visible(False)
axes.spines['bottom'].set_visible(False)

axes.xaxis.set_major_locator(NullLocator())
axes.yaxis.set_major_locator(NullLocator())

# %%
#Ejercicio 22.A
from sklearn.datasets import load_iris

iris=load_iris()
 
sepal_length=iris.data[:,0]
petal_length=iris.data[:,2]
flower_type=iris.target[:]
target_names=iris.target_names.tolist()

figure=plt.figure(figsize=(8,6))
axes = figure.add_subplot()

scatter=axes.scatter(x=sepal_length,y=petal_length,c=flower_type,cmap="brg")
axes.set_xlabel("Largo Sépalo")
axes.set_ylabel("Largo Pétalo")
legends=axes.legend(handles=scatter.legend_elements()[0],labels=target_names)

# %%
#Ejercicio 22.B
from sklearn.datasets import load_iris



iris=load_iris()
target_names=iris.target_names.tolist()
feature_names=iris.feature_names


def plot_single_scatter(axes,x,y,target,label_x,label_y):
    scatter=axes.scatter(x=x,y=y,c=target,cmap="brg")
    axes.set_xlabel(label_x)
    axes.set_ylabel(label_y)
    legends=axes.legend(handles=scatter.legend_elements()[0],labels=target_names)

figure=plt.figure(figsize=(8,6))
axes = figure.add_subplot()

index_x=0  #El 0 es el largo del sépalo
index_y=2  #El 2 es el largo del pétalo

x=iris.data[:,index_x]
y=iris.data[:,index_y]
target=iris.target[:]
label_x=feature_names[index_x]
label_y=feature_names[index_y]

plot_single_scatter(axes,x,y,target,label_x,label_y)

# %%
#Ejercicio 22.C
from sklearn.datasets import load_iris

iris=load_iris()
target_names=iris.target_names.tolist() 
feature_names=iris.feature_names



def plot_single_scatter(axes,x,y,target,label_x,label_y):
    scatter=axes.scatter(x=x,y=y,c=target,cmap="brg")
    axes.set_xlabel(label_x)
    axes.set_ylabel(label_y)
    legends=axes.legend(handles=scatter.legend_elements()[0],labels=target_names)


figure=plt.figure(figsize=(20,20))

numero_caracteristicas=len(feature_names)
total_numero_graficas=numero_caracteristicas**2

num_axes=0
for index_x in range(numero_caracteristicas):
    for index_y in range(numero_caracteristicas):
        x=iris.data[:,index_x]
        y=iris.data[:,index_y]
        target=iris.target[:]
        label_x=feature_names[index_x]
        label_y=feature_names[index_y]

        num_axes=num_axes+1
        if (index_x!=index_y):
            axes = figure.add_subplot(numero_caracteristicas,numero_caracteristicas,num_axes)
            plot_single_scatter(axes,x,y,target,label_x,label_y)

# %%
#Ejercicio 22.D
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import seaborn as sns

iris=load_iris()
target_names=iris.target_names.tolist()
feature_names=iris.feature_names


index_x=0  #El 0 es el largo del sépalo

x=iris.data[:,index_x]
target=iris.target[:]
label_x=feature_names[index_x]



figure=plt.figure(figsize = (6, 6))
axes = figure.add_subplot()

sns.kdeplot(x=x,hue=target,fill=True,ax=axes)
axes.set_xlabel(label_x)  
axes.set_ylabel('Densidad')
axes.legend(labels=target_names)

# %%
#Ejercicio 22.E
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris


iris=load_iris()
target_names=iris.target_names.tolist()
feature_names=iris.feature_names


def plot_single_kde(axes,x,target,label_x):
    sns.kdeplot(x=x,hue=target,fill=True,ax=axes)
    axes.set_xlabel(label_x)  
    axes.set_ylabel('Densidad')
    axes.legend(labels=target_names)

index_x=0  #El 0 es el largo del sépalo

x=iris.data[:,index_x]
target=iris.target[:]
label_x=feature_names[index_x]



figure=plt.figure(figsize = (6, 6))
axes = figure.add_subplot()
plot_single_kde(axes,x,target,label_x)

# %%
#Ejercicio 22.F
from sklearn.datasets import load_iris

iris=load_iris()
target_names=iris.target_names.tolist() 
feature_names=iris.feature_names



def plot_single_scatter(axes,x,y,target,label_x,label_y):
    scatter=axes.scatter(x=x,y=y,c=target,cmap="brg")
    axes.set_xlabel(label_x)
    axes.set_ylabel(label_y)
    legends=axes.legend(handles=scatter.legend_elements()[0],labels=target_names)


def plot_single_kde(axes,x,target,label_x):
    sns.kdeplot(x=x,hue=target,fill=True,ax=axes)
    axes.set_xlabel(label_x)  
    axes.set_ylabel('Densidad')
    axes.legend(labels=target_names)

figure=plt.figure(figsize=(20,20))

numero_caracteristicas=len(feature_names)
total_numero_graficas=numero_caracteristicas**2

num_axes=0
for index_x in range(numero_caracteristicas):
    for index_y in range(numero_caracteristicas):
        x=iris.data[:,index_x]
        y=iris.data[:,index_y]
        target=iris.target[:]
        label_x=feature_names[index_x]
        label_y=feature_names[index_y]


        num_axes=num_axes+1
        axes = figure.add_subplot(numero_caracteristicas,numero_caracteristicas,num_axes)
        if (index_x!=index_y):
            plot_single_scatter(axes,x,y,target,label_x,label_y)
        else:
            plot_single_kde(axes,x,target,label_x)

# %%
#Ejercicio 22.G
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.datasets import load_iris

iris=load_iris()


data=iris.data
target=iris.target

feature_names=['longitud sepalo ','ancho sepalo','longitud petalo','ancho petalo'] #iris.feature_names
target_names=['setosa', 'versicolor', 'virginica'] #iris.target_names
target_unique=[0,1,2] #np.unique(target)

df=pd.DataFrame(data, columns=feature_names)
df['flores']=target
df['flores'] = df['flores'].replace(target_unique,target_names)


sns.pairplot(df,hue="flores")

#La sorpresa es que es el mismo gŕafico que el anterior

# %%
#Ejercicio 23.A
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from sklearn.datasets import load_iris
from matplotlib.ticker import MaxNLocator
from matplotlib.ticker import MultipleLocator
import random


iris=load_iris()
 
sepal_length=iris.data[0:99,0]
petal_length=iris.data[0:99,2]
flower_type=iris.target[0:99]
 
x=np.column_stack((sepal_length,petal_length))
y=flower_type
 
 
np.random.seed(5)
tf.random.set_seed(5)
random.seed(5)  
 
model=Sequential()
model.add(Dense(6, activation='relu',input_dim=2))
model.add(Dense(12, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='mean_squared_error')
 
 
history=model.fit(x, y,epochs=40,verbose=False)



figure=plt.figure(figsize=(7, 5))
axes = figure.add_subplot(1,1,1)
axes.plot(history.history['loss'],linestyle="dotted",label=f"loss entrenamiento:{history.history['loss'][-1]:.02f}",color="#003B80")


axes.set_xlabel('Nº Épocas', fontsize=13,color="#003B80") 
axes.xaxis.set_major_locator(MaxNLocator(integer=True))

axes.set_ylabel('Métricas', fontsize=13,color="#003B80")
axes.set_ylim(ymin=0,ymax=1.1)
axes.yaxis.set_major_locator(MultipleLocator(0.1))

axes.set_title("Red:6,12,6,1")
axes.set_facecolor("#F0F7FF")
axes.grid(visible=True, which='major', axis='both',color="#FFFFFF",linewidth=2)
axes.legend()

# %%
#Ejercicio 23.B
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from sklearn.datasets import load_iris
from matplotlib.ticker import MaxNLocator
from matplotlib.ticker import MultipleLocator
import random


def plot_metrics(axes,history,title):
    axes.plot(history['loss'],linestyle="dotted",label=f"loss entrenamiento:{history['loss'][-1]:.02f}",color="#003B80")

    axes.set_xlabel('Nº Épocas', fontsize=13,color="#003B80") 
    axes.xaxis.set_major_locator(MaxNLocator(integer=True))

    axes.set_ylabel('Métricas', fontsize=13,color="#003B80")
    axes.set_ylim(ymin=0,ymax=1.1)
    axes.yaxis.set_major_locator(MultipleLocator(0.1))

    axes.set_title(title)
    axes.set_facecolor("#F0F7FF")
    axes.grid(visible=True, which='major', axis='both',color="#FFFFFF",linewidth=2)
    axes.legend()


iris=load_iris()
 
sepal_length=iris.data[0:99,0]
petal_length=iris.data[0:99,2]
flower_type=iris.target[0:99]
 
x=np.column_stack((sepal_length,petal_length))
y=flower_type
 
 
np.random.seed(5)
tf.random.set_seed(5)
random.seed(5)  
 
model=Sequential()
model.add(Dense(6, activation='relu',input_dim=2))
model.add(Dense(12, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='mean_squared_error')
 
 
history=model.fit(x, y,epochs=40,verbose=False)


figure=plt.figure(figsize=(7, 5))
axes = figure.add_subplot(1,1,1)

plot_metrics(axes,history.history,"Red:6,12,6,1")

# %%
#Ejercicio 23.C
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from matplotlib.colors import LightSource
from tabulate import tabulate
from time import perf_counter
from matplotlib.ticker import MaxNLocator
from matplotlib.ticker import MultipleLocator
import random



def get_datos():
    iris=load_iris()
    
    sepal_length=iris.data[0:99,0]
    petal_length=iris.data[0:99,2]
    flower_type=iris.target[0:99]
    
    x=np.column_stack((sepal_length,petal_length))
    y=flower_type

    return x,y
 
 

 
def compile_fit(capas,epochs,x,y):

    np.random.seed(5)
    tf.random.set_seed(5)
    random.seed(5)  

    model=Sequential()
    for index,neuronas_capa in enumerate(capas):
        if (index==0):
            model.add(Dense(neuronas_capa, activation='relu',input_dim=x.shape[1]))
        elif (index==len(capas)-1):
            model.add(Dense(neuronas_capa, activation='sigmoid'))          
        else:
            model.add(Dense(neuronas_capa, activation='relu'))

    model.compile(loss='mean_squared_error')
    history=model.fit(x,y,epochs=epochs,verbose=False) 

    return model,history
 
def plot_metrics(axes,history,title):
    axes.plot(history['loss'],linestyle="dotted",label=f"loss entrenamiento:{history['loss'][-1]:.02f}",color="#003B80")

    axes.set_xlabel('Nº Épocas', fontsize=13,color="#003B80") 
    axes.xaxis.set_major_locator(MaxNLocator(integer=True))

    axes.set_ylabel('Métricas', fontsize=13,color="#003B80")
    axes.set_ylim(ymin=0,ymax=1.1)
    axes.yaxis.set_major_locator(MultipleLocator(0.1))

    axes.set_title(title)
    axes.set_facecolor("#F0F7FF")
    axes.grid(visible=True, which='major', axis='both',color="#FFFFFF",linewidth=2)
    axes.legend()

x,y=get_datos()
redes=[  
  [4, 8, 4, 2, 1],
 [8, 16, 8, 4, 1],
 [16, 32, 16, 8, 1],
 [32, 64, 32, 8, 1],    
 [64, 128, 64, 8, 1],
]

epochs=40
figure=plt.figure(figsize=(20, 11))

for index,capas in enumerate(redes):
    model,history=compile_fit(capas,epochs,x,y)
    axes = figure.add_subplot(2,3,index+1)
    plot_metrics(axes,history.history,str(capas)) 


#1º Red: Se debería haber seguido entrenando.
#2º Red: Se debería haber seguido entrenando.
#3º Red: Se debería haber parado sobre la época 35.
#4º Red: Se debería haber parado sobre la época 20.
#5º Red: Se debería haber parado sobre la época 15.

#La mejor red parece la 4º ya que es la más estable comparada con la 5º que es más irregular en la 4º época y en la 34º

# %%
#Ejercicio 23.D
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from matplotlib.colors import LightSource
from tabulate import tabulate
from time import perf_counter
from matplotlib.ticker import MaxNLocator
from matplotlib.ticker import MultipleLocator
import random



def get_datos():
    iris=load_iris()
    
    sepal_length=iris.data[0:99,0]
    petal_length=iris.data[0:99,2]
    flower_type=iris.target[0:99]
    
    x=np.column_stack((sepal_length,petal_length))
    y=flower_type

    return x,y
 
 

 
def compile_fit(capas,epochs,x_train, x_test, y_train, y_test):

    np.random.seed(5)
    tf.random.set_seed(5)
    random.seed(5)  

    model=Sequential()
    for index,neuronas_capa in enumerate(capas):
        if (index==0):
            model.add(Dense(neuronas_capa, activation='relu',input_dim=x.shape[1]))
        elif (index==len(capas)-1):
            model.add(Dense(neuronas_capa, activation='sigmoid'))          
        else:
            model.add(Dense(neuronas_capa, activation='relu'))

    model.compile(loss='mean_squared_error')
    history=model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=epochs,verbose=False) 

    return model,history
 
def plot_metrics(axes,history,title):
    axes.plot(history['loss'],linestyle="dotted",label=f"loss entrenamiento:{history['loss'][-1]:.02f}",color="#003B80")
    axes.plot(history['val_loss'],linestyle="solid",label=f"loss validación:{history['val_loss'][-1]:.02f}",color="#003B80")

    axes.set_xlabel('Nº Épocas', fontsize=13,color="#003B80") 
    axes.xaxis.set_major_locator(MaxNLocator(integer=True))

    axes.set_ylabel('Métricas', fontsize=13,color="#003B80")
    axes.set_ylim(ymin=0,ymax=1.1)
    axes.yaxis.set_major_locator(MultipleLocator(0.1))

    axes.set_title(title)
    axes.set_facecolor("#F0F7FF")
    axes.grid(visible=True, which='major', axis='both',color="#FFFFFF",linewidth=2)
    axes.legend()

x,y=get_datos()
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
redes=[  
  [4, 8, 4, 2, 1],
 [8, 16, 8, 4, 1],
 [16, 32, 16, 8, 1],
 [32, 64, 32, 8, 1],    
 [64, 128, 64, 8, 1],
]

epochs=40
figure=plt.figure(figsize=(20, 11))

for index,capas in enumerate(redes):
    model,history=compile_fit(capas,epochs,x_train, x_test, y_train, y_test)
    axes = figure.add_subplot(2,3,index+1)
    plot_metrics(axes,history.history,str(capas)) 


#1º Red: Se debería haber seguido entrenando.
#2º Red: Se debería haber seguido entrenando.
#3º Red: Se debería haber parado sobre la época 35.
#4º Red: Se debería haber parado sobre la época 20.
#5º Red: Se debería haber parado sobre la época 15.

#La mejor red parece la 4º ya que es la más estable comparada con la 5º que es más irregular en la 4º época y en la 34º
