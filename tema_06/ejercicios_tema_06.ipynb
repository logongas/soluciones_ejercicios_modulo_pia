# %% [markdown]
# ## Ejercicio 1.A
#
#
#
# *  Indica las fórmulas de cada una de las neuronas suponiendo que no hay función de activacion:
#
# $$y_0=w_{0}x_{0}+w_{1}x_{1}+b$$
#
# * Indica el Nª de capas
#   * Entrada: 1
#   * Salida: 1
#   * Ocultas: 0
# * Para cada neurona
#   * Indica el nº parámetros: 3
#   * Indica en nº de entradas: 2
#   * Indica en nº de salidas: 1
# * Para cada capa
#   * Indica el nº parámetros: 3
#   * Indica en nº de entradas: 2
#   * Indica en nº de salidas: 1
# * Para toda la red:
#   * Indica el nº parámetros: 3
#   * Indica en nº de entradas: 2
#   * Indica en nº de salidas: 1

# %%
#Ejercicio 1.A

#Crea el código en Keras de la red neuronal.

import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.utils import plot_model
import random
 
np.random.seed(5)
tf.random.set_seed(5)
random.seed(5)  

model=Sequential()
model.add(Dense(1, input_dim=2))
model.compile(loss='mean_squared_error')

# Muestra el resumen de la red en Keras y comprueba que coincide con lo calculado

model.summary()

# Muestra el grafico de la red en Keras y comprueba que coincide con lo calculado

plot_model(model, show_shapes=True)
# Out:
# 2023-02-02 20:53:36.211500: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-02 20:53:36.211516: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 3
#
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# 2023-02-02 20:53:37.223289: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# ...

# %%
#Ejercicio 1.A

# Imprime por pantalla el valor de cada uno de los peso

def get_w(model,layer,neuron,index):
    layer=model.layers[layer]
    return layer.get_weights()[0][index,neuron]
 
 
 
def get_b(model,layer,neuron):
    layer=model.layers[layer]
    return layer.get_weights()[1][neuron]


w_0=get_w(model,0,0,0)
w_1=get_w(model,0,0,1)
b=get_b(model,0,0)

print("w_0=",w_0)
print("w_1=",w_0)
print("b=",b)
# Out:
# w_0= 0.35749364
# w_1= 0.35749364
# b= 0.0

# %%
#Ejercicio 1.B
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
 
np.random.seed(5)
tf.random.set_seed(5)
random.seed(5) 

model=Sequential()
model.add(Dense(1, input_dim=2,activation="sigmoid"))
model.compile(loss='mean_squared_error')

# %% [markdown]
# ## Ejercicio 1.B
#
# $$y_0=\frac{1}{1 + e^{-(w_{0}x_{0}+w_{1}x_{1}+b)}}$$

# %%
#Ejercicio 1.C
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
 
np.random.seed(5)
tf.random.set_seed(5)
random.seed(5) 

model=Sequential()
model.add(Dense(1, input_dim=2,activation="tanh"))
model.compile(loss='mean_squared_error')

# %% [markdown]
# ## Ejercicio 1.C
#
# $$
# y_0=\frac{e^{(w_{0}x_{0}+w_{1}x_{1}+b)} - e^{-(w_{0}x_{0}+w_{1}x_{1}+b)}}{e^{(w_{0}x_{0}+w_{1}x_{1}+b)} + e^{-(w_{0}x_{0}+w_{1}x_{1}+b)}}
# $$

# %% [markdown]
# ## Ejercicio 2.A
#
# *  Indica las fórmulas de cada una de las neuronas suponiendo que no hay función de activacion:
#
# $$y_3=w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3}$$
#
# $$y_4=w_{4\_0}y_3+b_{4}$$
# $$\Downarrow$$
# $$y_4=w_{4\_0}(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})+b_{4}$$
#
# * Indica el Nª de capas
#   * Entrada: 1
#   * Salida: 1
#   * Ocultas: 1
# * Para cada neurona
#   * Neurona 3
#     * Indica el nº parámetros: 3
#     * Indica en nº de entradas: 2
#     * Indica en nº de salidas: 1
#   * Neurona 4
#     * Indica el nº parámetros: 2
#     * Indica en nº de entradas: 1
#     * Indica en nº de salidas: 1
# * Para cada capa
#   * Capa oculta
#     * Indica el nº parámetros: 3
#     * Indica en nº de entradas: 2
#     * Indica en nº de salidas: 1
#   * Capa Salida
#     * Indica el nº parámetros: 2
#     * Indica en nº de entradas: 1
#     * Indica en nº de salidas: 1
# * Para toda la red:
#   * Indica el nº parámetros: 5
#   * Indica en nº de entradas: 3
#   * Indica en nº de salidas: 2

# %%
#Ejercicio 2.A

#Crea el código en Keras de la red neuronal.

import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.utils import plot_model
 
np.random.seed(5)
tf.random.set_seed(5)
random.seed(5) 
  
model=Sequential()
model.add(Dense(1, input_dim=2))
model.add(Dense(1))
model.compile(loss='mean_squared_error')

# Muestra el resumen de la red en Keras y comprueba que coincide con lo calculado

model.summary()

# Muestra el grafico de la red en Keras y comprueba que coincide con lo calculado

plot_model(model, show_shapes=True)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 1)                 3
#
#  dense_4 (Dense)             (None, 1)                 2
#
# ...
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Ejercicio 2.A

# Imprime por pantalla el valor de cada uno de los peso

def get_w(model,layer,neuron,index):
    layer=model.layers[layer]
    return layer.get_weights()[0][index,neuron]
 
 
 
def get_b(model,layer,neuron):
    layer=model.layers[layer]
    return layer.get_weights()[1][neuron]


w_3_0=get_w(model,0,0,0)
w_3_1=get_w(model,0,0,1)
w_4_0=get_w(model,1,0,0)
b_3=get_b(model,0,0)
b_4=get_b(model,1,0)

print("w_3_0=",w_3_0)
print("w_3_1=",w_3_1)
print("w_4_0=",w_4_0)
print("b_3=",b_3)
print("b_4=",b_4)
# Out:
# w_3_0= 0.35749364
# w_3_1= 0.084409356
# w_4_0= 0.6987351
# b_3= 0.0
# b_4= 0.0

# %%
#Ejercicio 2.B

import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.utils import plot_model
 
np.random.seed(5)
tf.random.set_seed(5)
random.seed(5) 
  
model=Sequential()
model.add(Dense(1, input_dim=2,activation="sigmoid"))
model.add(Dense(1,activation="sigmoid"))
model.compile(loss='mean_squared_error')

# %% [markdown]
# ## Ejercicio 2.B
#
# $$y_3=\frac{1}{1 + e^{-(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})}}$$
#
# $$y_4=\frac{1}{1 + e^{-(w_{4\_0}y_3+b_{4})}}$$
# $$\Downarrow$$
# $$y_4=\frac{1}{1 + e^{-(\frac{1}{1 + e^{-(w_{4\_0}y_3+b_{4})}})}}$$

# %%
#Ejercicio 2.C

import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.utils import plot_model
 
np.random.seed(5)
tf.random.set_seed(5)
random.seed(5) 

model=Sequential()
model.add(Dense(1, input_dim=2,activation="tanh"))
model.add(Dense(1,activation="tanh"))
model.compile(loss='mean_squared_error')

# %% [markdown]
# ## Ejercicio 2.C
#
#
# $$y_3=\frac{e^{(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})} - e^{-(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})}}{e^{(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})} + e^{-(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})}}$$
#
# $$y_4=\frac{e^{(w_{4\_0}y_3+b_{4})} - e^{-(w_{4\_0}y_3+b_{4})}}{e^{(w_{4\_0}y_3+b_{4})} + e^{-(w_{4\_0}y_3+b_{4})}}$$
# $$\Downarrow$$
#
#
# $$y_4=\frac{e^{(w_{4\_0}(\frac{e^{(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})} - e^{-(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})}}{e^{(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})} + e^{-(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})}})+b_{4})} - e^{-(w_{4\_0}(\frac{e^{(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})} - e^{-(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})}}{e^{(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})} + e^{-(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})}})+b_{4})}}{e^{(w_{4\_0}(\frac{e^{(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})} - e^{-(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})}}{e^{(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})} + e^{-(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})}})+b_{4})} + e^{-(w_{4\_0}(\frac{e^{(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})} - e^{-(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})}}{e^{(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})} + e^{-(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})}})+b_{4})}}$$

# %% [markdown]
# ## Ejercicio 3
#
# * Indica el Nª de capas
#   * Entrada: 1
#   * Salida: 1
#   * Ocultas: 3
# * Para cada capa
#   * Capa oculta 1
#     * Indica el nº parámetros: 24
#     * Indica en nº de entradas: 3
#     * Indica en nº de salidas: 6
#   * Capa oculta 2
#     * Indica el nº parámetros: 56
#     * Indica en nº de entradas: 6
#     * Indica en nº de salidas: 8
#   * Capa oculta 3
#     * Indica el nº parámetros: 36
#     * Indica en nº de entradas: 8
#     * Indica en nº de salidas: 4
#   * Capa Salida
#     * Indica el nº parámetros: 10
#     * Indica en nº de entradas: 4
#     * Indica en nº de salidas: 2
# * Para toda la red:
#   * Indica el nº parámetros: 126
#   * Indica en nº de entradas: 3
#   * Indica en nº de salidas: 2

# %%
#Ejercicio 3

# Crea el código en Keras de la red neuronal

import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.utils import plot_model
 
np.random.seed(5)
tf.random.set_seed(5)
random.seed(5) 

model=Sequential()
model.add(Dense(6, input_dim=3))
model.add(Dense(8))
model.add(Dense(4))
model.add(Dense(2))
model.compile(loss='mean_squared_error')

# Muestra el resumen de la red en Keras y comprueba que coincide con lo calculado

model.summary()

# Muestra el grafico de la red en Keras y comprueba que coincide con lo calculado

plot_model(model, show_shapes=True)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 6)                 24
#
#  dense_10 (Dense)            (None, 8)                 56
#
#  dense_11 (Dense)            (None, 4)                 36
#
#  dense_12 (Dense)            (None, 2)                 10
#
# ...
# Total params: 126
# Trainable params: 126
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Ejercicio 4.A
#
# $$y_3=\frac{1}{1 + e^{-(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})}}$$
#
# $$y_4=\frac{1}{1 + e^{-(w_{4\_0}y_3+b_{4})}}$$
# $$\Downarrow$$
#
# $$y_4=\frac{1}{1 + e^{-(w_{4\_0}(\frac{1}{1 + e^{-(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})}})+b_{4})}}$$

# %%
# Ejercicio 4.A

# Crea la red en Keras
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.utils import plot_model
 
np.random.seed(5)
tf.random.set_seed(5)
random.seed(5) 

model=Sequential()
model.add(Dense(1, input_dim=2,activation="sigmoid"))
model.add(Dense(1,activation="sigmoid"))
model.compile(loss='mean_squared_error')

# Obtén el valor de los parámetros.

def get_w(model,layer,neuron,index):
    layer=model.layers[layer]
    return layer.get_weights()[0][index,neuron]
 
 
 
def get_b(model,layer,neuron):
    layer=model.layers[layer]
    return layer.get_weights()[1][neuron]


w_3_0=get_w(model,0,0,0)
w_3_1=get_w(model,0,0,1)
w_4_0=get_w(model,1,0,0)
b_3=get_b(model,0,0)
b_4=get_b(model,1,0)


print("w_3_0=",w_3_0)
print("w_3_1=",w_3_1)
print("w_4_0=",w_4_0)
print("b_3=",b_3)
print("b_4=",b_4)
# Out:
# w_3_0= 0.35749364
# w_3_1= 0.084409356
# w_4_0= 0.6987351
# b_3= 0.0
# b_4= 0.0

# %% [markdown]
# # Ejercicio 4.A
# ###Modifica la fórmula poniendo el valor de los parámetros.
#
# Las formulas:
#
# $$y_3=\frac{1}{1 + e^{-(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})}}$$
#
# $$y_4=\frac{1}{1 + e^{-(w_{4\_0}y_3+b_{4})}}$$
# $$\Downarrow$$
#
# $$y_4=\frac{1}{1 + e^{-(w_{4\_0}(\frac{1}{1 + e^{-(w_{3\_0}x_{0}+w_{3\_1}x_{1}+b_{3})}})+b_{4})}}$$
#
#
# substitución de los valores:
#
#   * $w_{3\_0}= 0.35749364$
#   * $w_{3\_1}= 0.084409356$
#   * $w_{4\_0}= 0.6987351$
#   * $b_{3}= 0.0$
#   * $b_{4}= 0.0$
#
# $$y_3=\frac{1}{1 + e^{-(0.35749364x_{0}+0.084409356x_{1}+0)}}$$
#
# $$y_4=\frac{1}{1 + e^{-(0.6987351y_3+0)}}$$
#
# $$\Downarrow$$
#
# $$y_4=\frac{1}{1 + e^{-(0.6987351(\frac{1}{1 + e^{-(0.35749364x_{0}+0.084409356x_{1}+0)}})+0)}}$$

# %%
# Ejercicio 4.A 

# Aplica la fórmula con los valores de entrada 4.7 y 1.3 y calcula el resultado.

def sigmoid(z):
    return 1/(1 + np.exp(-z))
 
def predict_formula(x):
    y_3=sigmoid(0.35749364*x[0]+0.084409356*x[1]+0)
    y_4=sigmoid(0.6987351*y_3+0)
 
    return y_4


resultado=predict_formula([4.7,1.3])
print("resultado formula=",resultado)

# Usando el método predict calcula lo que da la red de keras y comprueba que coincide con el calculado.

resultado=model.predict([[4.7,1.3]],verbose=False)
print("resultado predict=",resultado[0][0])
# Out:
# resultado formula= 0.6453728091293859
# resultado predict= 0.6453728

# %%
# Ejercicio 4.B
from sklearn.datasets import load_iris

iris=load_iris()
 
sepal_length=iris.data[0:99,0]
petal_length=iris.data[0:99,2]
flower_type=iris.target[0:99]
 
x=np.column_stack((sepal_length,petal_length))
y=flower_type

model.fit(x, y,epochs=200,verbose=False) 

w_3_0=get_w(model,0,0,0)
w_3_1=get_w(model,0,0,1)
w_4_0=get_w(model,1,0,0)
b_3=get_b(model,0,0)
b_4=get_b(model,1,0)

print("w_3_0=",w_3_0)
print("w_3_1=",w_3_1)
print("w_4_0=",w_4_0)
print("b_3=",b_3)
print("b_4=",b_4)
# Out:
# w_3_0= -0.093137264
# w_3_1= 0.5112498
# w_4_0= 0.67556536
# b_3= -0.54048055
# b_4= -0.29894146

# %%
def sigmoid(z):
    return 1/(1 + np.exp(-z))
 
def predict_formula(x):
    y_3=sigmoid(-0.093137264*x[0]+0.5112498*x[1]-0.5404806)
    y_4=sigmoid( 0.67556536*y_3-0.29894146)
 
    return y_4

y_predicho_red_neuronal=model.predict([x],verbose=False)
y_predicho_formula=[predict_formula(valores) for valores in x]

	
	
np.column_stack((y_predicho_red_neuronal,y_predicho_formula))
# Out:
# array([[0.49714875, 0.49714875],
#        [0.49791887, 0.49791888],
#        [0.4965767 , 0.4965767 ],
#        [0.5012086 , 0.50120861],
#        [0.49753356, 0.49753355],
#        [0.50236952, 0.50236954],
#        [0.4990778 , 0.4990778 ],
#        [0.49965465, 0.49965465],
#        [0.49985272, 0.49985272],
#        [0.50004256, 0.50004253],
#        [0.49810758, 0.49810756],
#        [0.5025689 , 0.50256893],
#        [0.49830469, 0.4983047 ],
#        [0.49391344, 0.49391345],
#        [0.49033707, 0.49033708],
#        [0.49695241, 0.4969524 ],
#        [0.49390525, 0.49390526],
#        [0.49714875, 0.49714875],
#        [0.5012002 , 0.50120021],
#        [0.49926719, 0.49926719],
#        [0.50236952, 0.50236954],
#        [0.49926719, 0.49926719],
#        [0.49071795, 0.49071795],
#        [0.50354171, 0.50354169],
#        [0.50902683, 0.50902681],
#        [0.50178868, 0.5017887 ],
#        [0.50178868, 0.5017887 ],
#        [0.49888018, 0.49888018],
# ...

# %%
# Ejercicicio 5.A

def get_model(capas,activation,kernel_initializer):

    np.random.seed(5)
    tf.random.set_seed(5)
    random.seed(5) 

    model=Sequential()
    for index,neuronas_capa in enumerate(capas):
        if (index==0):
            model.add(Dense(neuronas_capa, activation=activation,input_dim=2,kernel_initializer=kernel_initializer))
        elif (index==len(capas)-1):
            model.add(Dense(neuronas_capa, activation='sigmoid'))          
        else:
            model.add(Dense(neuronas_capa, activation=activation,kernel_initializer=kernel_initializer))

    model.compile(loss='mean_squared_error')
  

    return model


model=get_model([2,4,8,4,1],"tanh","glorot_normal")
model=get_model([2,4,8,4,1],tf.keras.activations.tanh,"glorot_normal")

# %%
# Ejercicio 5.B

model=get_model([2,4,8,4,1],"relu","he_uniform")
model=get_model([2,4,8,4,1],tf.keras.activations.relu,"he_uniform")
model=get_model([2,4,8,4,1],tf.keras.layers.ReLU(),"he_uniform")

# %%
# Ejercicio 5.C

model=get_model([2,4,8,4,1],tf.keras.layers.LeakyReLU(),"he_uniform")
model=get_model([2,4,8,4,1],tf.keras.layers.LeakyReLU(alpha=0.3),"he_uniform")

# %%
# Ejercicio 5.D

model=get_model([2,4,8,4,1],"selu","lecun_normal")
model=get_model([2,4,8,4,1],tf.keras.activations.selu,"lecun_normal")

# %%
# Ejercicio 5.E

model=get_model([2,4,8,4,1],tf.keras.layers.ELU(alpha=0.2),"lecun_normal")

# %%
# Ejercicio 5.F


model=Sequential()
model.add(Dense(2, activation="tanh"                               ,kernel_initializer="glorot_normal",input_dim=2))
model.add(Dense(4, activation=tf.keras.activations.relu            ,kernel_initializer="he_uniform"))
model.add(Dense(8, activation=tf.keras.layers.LeakyReLU(alpha=0.35),kernel_initializer="he_uniform"))
model.add(Dense(4, activation="selu"                               ,kernel_initializer="lecun_normal"))
model.add(Dense(2, activation=tf.keras.layers.ELU(alpha=0.2)       ,kernel_initializer="lecun_normal"))
model.add(Dense(1, activation="sigmoid"                            ,kernel_initializer="glorot_normal"))

model.compile(loss='mean_squared_error')

# %%
# Ejercicio 6.A

import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from sklearn.datasets import load_iris
from matplotlib.colors import LightSource
from tabulate import tabulate
from time import perf_counter
from sklearn.datasets import load_breast_cancer
from matplotlib.ticker import MaxNLocator
from matplotlib.ticker import MultipleLocator
from sklearn.model_selection import train_test_split

tf.get_logger().setLevel('ERROR')

def get_datos():
    breast_cancer=load_breast_cancer()

    x=breast_cancer.data
    y=breast_cancer.target

 
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

    return x_train, x_test, y_train, y_test
 
 

 
def compile_fit(capas,activation,kernel_initializer,epochs,input_dim,x_train, x_test, y_train, y_test):

    np.random.seed(5)
    tf.random.set_seed(5)
    random.seed(5)
    
    model=Sequential()
    for index,neuronas_capa in enumerate(capas):
        if (index==0):
            model.add(Dense(neuronas_capa, activation=activation,input_dim=input_dim,kernel_initializer=kernel_initializer))
        elif (index==len(capas)-1):
            model.add(Dense(neuronas_capa, activation='sigmoid',kernel_initializer="glorot_normal"))          
        else:
            model.add(Dense(neuronas_capa, activation=activation,kernel_initializer=kernel_initializer))

    model.compile(loss='mean_squared_error')
    
    history=model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=epochs,verbose=False) 

    return history
 

def plot_metrics(axes,history,title):
    loss_entrenamiento=round(history['loss'][-1],2) 
    loss_validacion=round(history['val_loss'][-1],2) 

    axes.plot(history['loss'],linestyle="dotted",label="loss entrenamiento:"+ str(loss_entrenamiento),c="#003B80")  
    axes.plot(history['val_loss'],linestyle="solid",label="loss validación:"+ str(loss_validacion),c="#003B80")

    axes.set_xlabel('Nº Épocas', fontsize=13,color="#003B80") 
    axes.xaxis.set_major_locator(MaxNLocator(integer=True))

    axes.set_ylabel('Métricas', fontsize=13,color="#003B80")
    axes.set_ylim(ymin=0,ymax=1.1)
    axes.yaxis.set_major_locator(MultipleLocator(0.1))

    axes.set_title(title)
    axes.set_facecolor("#F0F7FF")
    axes.grid(visible=True, which='major', axis='both',color="#FFFFFF",linewidth=2)
    axes.legend()

# %%
# Ejercicio 6.A

x_train, x_test, y_train, y_test=get_datos()


epochs=100
input_dim=30
activation="selu"
capas=[2,5,10,15,20,15,10,5,2,1]

history_lecun_normal  = compile_fit(capas,activation,"lecun_normal"  ,epochs,input_dim,x_train, x_test, y_train, y_test)
history_he_normal     = compile_fit(capas,activation,"he_normal"     ,epochs,input_dim,x_train, x_test, y_train, y_test)
history_glorot_normal = compile_fit(capas,activation,"glorot_normal" ,epochs,input_dim,x_train, x_test, y_train, y_test)

figure=plt.figure(figsize=(21, 5.5))
figure.suptitle("Inicializadores con SeLU para redes NO profundas", fontsize=25, color='#003B80')
axes = figure.add_subplot(1,3,1)
plot_metrics(axes,history_lecun_normal.history,"Lecun normal")
axes = figure.add_subplot(1,3,2)
plot_metrics(axes,history_he_normal.history,"He normal")
axes = figure.add_subplot(1,3,3)
plot_metrics(axes,history_glorot_normal.history,"Glorot normal")

#La teoría dice el inicializador debería ser "LeCum Normal" pero tampoco hay mucha diferencia

# %%
# Ejercicio 6.B

x_train, x_test, y_train, y_test=get_datos()


epochs=100
input_dim=30
activation="selu"
capas=[5,10,15,20,25,30,35,40,45,50,55,60,65,70,75,70,65,60,55,50,45,40,35,30,25,20,15,10,5,1]

history_lecun_normal  = compile_fit(capas,activation,"lecun_normal"  ,epochs,input_dim,x_train, x_test, y_train, y_test)
history_he_normal     = compile_fit(capas,activation,"he_normal"     ,epochs,input_dim,x_train, x_test, y_train, y_test)
history_glorot_normal = compile_fit(capas,activation,"glorot_normal" ,epochs,input_dim,x_train, x_test, y_train, y_test)

figure=plt.figure(figsize=(21, 5.5))
figure.suptitle("Inicializadores con SeLU para redes profundas", fontsize=25, color='#003B80')
axes = figure.add_subplot(1,3,1)
plot_metrics(axes,history_lecun_normal.history,"Lecun normal")
axes = figure.add_subplot(1,3,2)
plot_metrics(axes,history_he_normal.history,"He normal")
axes = figure.add_subplot(1,3,3)
plot_metrics(axes,history_glorot_normal.history,"Glorot normal")

#La teoría dice el inicializador debería ser "LeCum Normal" pero ahora hay diferencia con respecto a "He Normal"

# %%
# Ejercicio 7

x_train, x_test, y_train, y_test=get_datos()


epochs=100
input_dim=30
capas=[16,32,64,127,64,32,16,8,1]
kernel_initializer="glorot_uniform"

activations=[
        ("Sigmoid","sigmoid"),
        ("Tan Hiperbolica","tanh"),
        ("ReLU","relu"),
        ("Leaky ReLU",tf.keras.layers.LeakyReLU()),
        ("ELU","elu"),
        ("SeLU","selu")]

index=1
figure=plt.figure(figsize=(21, 12))
for caption,activation in activations:
  history=compile_fit(capas,activation,kernel_initializer,epochs,input_dim,x_train, x_test, y_train, y_test)
  axes = figure.add_subplot(2,3,index)
  plot_metrics(axes,history.history,caption)
  index=index+1

# ELU y SeLU dan mejor resultado

# %% [markdown]
# ## Ejercicio 8
#
#   * Averiguar si un paciente tendrá diabetes en el futuro según una serie de analíticas que se han ido haciendo a lo largo de su vida.
#     * Sigmoide-1
#   * Distinguir entre 5 tipos de vino según distintas características del vino
#     * Softmax-5
#   * Indicar las variedades de olivas que lleva un aceite y su proporción según el análisis químico que se le hace al aceite.
#     * Linear-5
#   * Indicar si una compra con tarjeta es fraudulenta
#     * Sigmoide-1
#   * Averiguar a que partido político ha votado una persona
#     * Softmax-Nº de partidos
#   * Averiguar la distancia a la que se encuentra una estrella según diversas fotos que se van sacando de ella con telescopios.
#     * Linear-1
#   * Entre 8 tipos distintos de canceres y dada la foto de las células de una persona averiguar los cánceres que puede tener
#     * Sigmoide-8
#   * Saber el tipo de tiburón según el sonido que hace bajo el agua al desplazarse
#     * Softmax-Nº de tipos de tiburones
#   * Calcular la ubicación de los objetivos a destruir por un tanque  según los sensores proporcionados por el tanque
#     * Linear-Nº maximo de objetivos que permita el tanque
#   * Averiguar la cifra que se ha escrito una persona a mano.
#     * Softmax-10

# %%
# Ejercicio 9.A

def compile_fit(capas,activation,last_activation,epochs,input_dim,x_train, x_test, y_train, y_test):

    np.random.seed(5)
    tf.random.set_seed(5)
    random.seed(5)
    
    model=Sequential()
    for index,neuronas_capa in enumerate(capas):
        if (index==0):
            model.add(Dense(neuronas_capa, activation=activation,input_dim=input_dim))
        elif (index==len(capas)-1):
            model.add(Dense(neuronas_capa, activation=last_activation))          
        else:
            model.add(Dense(neuronas_capa, activation=activation))

    model.compile(loss='mean_squared_error')
    
    history=model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=epochs,verbose=False) 

    return history

# %%
# Ejercicio 9.A
from sklearn.datasets import load_iris
from sklearn.preprocessing import LabelBinarizer

def get_datos():
  datos=load_iris()
  x=datos.data
  y=datos.target
  label_binarizer = LabelBinarizer()
  label_binarizer.fit(range(max(y)+1))
  y = label_binarizer.transform(y)

  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

  return x_train, x_test, y_train, y_test

x_train, x_test, y_train, y_test=get_datos()


epochs=20
input_dim=x_train.shape[1]
capas=[8,16,32,64,32,16,8,3]
kernel_initializer="glorot_uniform"

activations=[
        ("Sigmoid","sigmoid"),
        ("Tan Hiperbolica","tanh"),
        ("ReLU","relu"),
        ("Leaky ReLU",tf.keras.layers.LeakyReLU()),
        ("ELU","elu"),
        ("SeLU","selu")]

index=1
figure=plt.figure(figsize=(21, 12))
for caption,activation in activations:
  history=compile_fit(capas,activation,"softmax",epochs,input_dim,x_train, x_test, y_train, y_test)
  axes = figure.add_subplot(2,3,index)
  plot_metrics(axes,history.history,caption)
  index=index+1

# %%
# Ejercicio 9.B
from sklearn.datasets import load_wine
from sklearn.preprocessing import LabelBinarizer

def get_datos():
  datos=load_wine()
  x=datos.data
  y=datos.target
  label_binarizer = LabelBinarizer()
  label_binarizer.fit(range(max(y)+1))
  y = label_binarizer.transform(y)
  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

  return x_train, x_test, y_train, y_test

x_train, x_test, y_train, y_test=get_datos()


epochs=20
input_dim=x_train.shape[1]
capas=[8,16,32,64,32,16,8,3]
kernel_initializer="glorot_uniform"

activations=[
        ("Sigmoid","sigmoid"),
        ("Tan Hiperbolica","tanh"),
        ("ReLU","relu"),
        ("Leaky ReLU",tf.keras.layers.LeakyReLU()),
        ("ELU","elu"),
        ("SeLU","selu")]

index=1
figure=plt.figure(figsize=(21, 12))
for caption,activation in activations:
  history=compile_fit(capas,activation,"softmax",epochs,input_dim,x_train, x_test, y_train, y_test)
  axes = figure.add_subplot(2,3,index)
  plot_metrics(axes,history.history,caption)
  index=index+1

# %%
# Ejercicio 9.C
from sklearn.datasets import load_digits
from sklearn.preprocessing import LabelBinarizer

def get_datos():
  datos=load_digits()
  x=datos.data
  y=datos.target
  label_binarizer = LabelBinarizer()
  label_binarizer.fit(range(max(y)+1))
  y = label_binarizer.transform(y)

  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

  return x_train, x_test, y_train, y_test

x_train, x_test, y_train, y_test=get_datos()


epochs=20
input_dim=x_train.shape[1]
capas=[8,16,32,64,32,16,10]
kernel_initializer="glorot_uniform"

activations=[
        ("Sigmoid","sigmoid"),
        ("Tan Hiperbolica","tanh"),
        ("ReLU","relu"),
        ("Leaky ReLU",tf.keras.layers.LeakyReLU()),
        ("ELU","elu"),
        ("SeLU","selu")]

index=1
figure=plt.figure(figsize=(21, 12))
for caption,activation in activations:
  history=compile_fit(capas,activation,"softmax",epochs,input_dim,x_train, x_test, y_train, y_test)
  axes = figure.add_subplot(2,3,index)
  plot_metrics(axes,history.history,caption)
  index=index+1

# %%
# Ejercicio 9.D
from sklearn.datasets import load_diabetes

def get_datos():
  datos=load_diabetes()
  x=datos.data
  y=datos.target

  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

  return x_train, x_test, y_train, y_test

x_train, x_test, y_train, y_test=get_datos()


epochs=150
input_dim=x_train.shape[1]
capas=[8,16,32,64,32,16,8,1]
kernel_initializer="glorot_uniform"

activations=[
        ("Sigmoid","sigmoid"),
        ("Tan Hiperbolica","tanh"),
        ("ReLU","relu"),
        ("Leaky ReLU",tf.keras.layers.LeakyReLU()),
        ("ELU","elu"),
        ("SeLU","selu")]

index=1
figure=plt.figure(figsize=(21, 12))
for caption,activation in activations:
  history=compile_fit(capas,activation,"linear",epochs,input_dim,x_train, x_test, y_train, y_test)
  axes = figure.add_subplot(2,3,index)
  plot_metrics(axes,history.history,caption)
  axes.set_ylim(ymin=2500,ymax=3500)
  axes.yaxis.set_major_locator(MultipleLocator(200))
  index=index+1


#Los errores son enormes

# %%
#Ejercicio 10
from sklearn.datasets import load_wine
from sklearn.preprocessing import LabelBinarizer

def array_to_str(datos):
    s=""
    for index,dato in enumerate(datos):
        if (index==0):
            s=str(dato)
        else:
            s=s+","+str(dato)

    return s

def get_datos():
  datos=load_wine()
  x=datos.data
  y=datos.target
  label_binarizer = LabelBinarizer()
  label_binarizer.fit(range(max(y)+1))
  y = label_binarizer.transform(y)
  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

  return x_train, x_test, y_train, y_test

x_train, x_test, y_train, y_test=get_datos()


epochs=100
input_dim=x_train.shape[1]
capas_redes=[[2,4,3],[4,8,3],[8,16,8,3],[4,8,4,3],[8,16,8,3],[16,32,16,8,3],[32,64,32,8,3],[64,128,64,8,3],[8,16,32,64,32,16,8,3]]
kernel_initializer="glorot_uniform"

activations=[
        ("ReLU","relu"),
        ("Leaky ReLU",tf.keras.layers.LeakyReLU()),
        ("ELU","elu"),
        ("SeLU","selu")]

index=1
figure=plt.figure(figsize=(7*len(activations), 7*len(capas_redes)))
for capas in capas_redes:
  for caption,activation in activations:
    history=compile_fit(capas,activation,"softmax",epochs,input_dim,x_train, x_test, y_train, y_test)
    axes = figure.add_subplot(len(capas_redes),len(activations),index)
    plot_metrics(axes,history.history,array_to_str(capas)+","+caption)
    index=index+1
